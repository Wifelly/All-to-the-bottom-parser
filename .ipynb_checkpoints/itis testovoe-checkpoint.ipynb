# %%
import pandas as pd
import numpy as np

# %%
cleared_lines = []
with open('logs.txt') as f:
    for line in f.readlines():
        cleared_line = " ".join(line.replace('|','').split()).split()
        cleared_line[6] = cleared_line[6].replace('https://all_to_the_bottom.com/', '')
        if cleared_line[6] == '':
            cleared_line[6] = 'index'
        cleared_line[1] = cleared_line[1] + ' ' + cleared_line[2]
        cleared_lines.append(cleared_line)

df = pd.DataFrame(cleared_lines, columns=[0, 'date', 'time', 'id', 4, 'ip', 'action']).drop([0, 4], axis=1)
df = df.replace('', np.nan).dropna()
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                       date      time          id               ip  \
# 0      2018-08-01 00:01:35  00:01:35  [YQ4WUDJV]  121.165.118.201
# 1      2018-08-01 00:01:47  00:01:47  [E522JAEQ]  121.165.118.201
# 2      2018-08-01 00:03:02  00:03:02  [BHWP66G8]  121.165.118.201
# 3      2018-08-01 00:04:27  00:04:27  [C0182Y6W]  121.165.118.201
# 4      2018-08-01 00:05:55  00:05:55  [OJKTKNP6]  121.165.118.201
# ...                    ...       ...         ...              ...
# 24279  2018-08-14 09:52:25  09:52:25  [9SDDN7VV]   147.144.255.18
# 24280  2018-08-14 09:53:06  09:53:06  [PANSGPA1]   147.144.255.18
# 24281  2018-08-14 09:53:56  09:53:56  [QBV4IHFK]   147.144.255.18
# 24282  2018-08-14 09:53:56  09:53:56  [ZLZ4QXWB]   147.144.255.18
# 24283  2018-08-14 09:53:56  09:53:56  [2O1CTP7M]   147.144.255.18
#
#                                      action
# 0                                     index
# 1                               fresh_fish/
# 2                                     index
# 3                              canned_food/
# 4                                     index
# ...                                     ...
# 24279                                 index
# 24280                          canned_food/
# 24281             canned_food/pate_of_tuna/
# 24282  pay?user_id=81416246280&cart_id=9790
# 24283                     success_pay_9790/
#
# [24284 rows x 5 columns]

# %%
# df.
for i, item in enumerate(df.action):
    if item.count('/') == 1:
        print(item.split('/'), i)
    if item.count('/') == 2:
        print(item.split('/'), i)
# Out:
# ['fresh_fish', ''] 1
# ['canned_food', ''] 3
# ['semi_manufactures', ''] 5
# ['canned_food', ''] 6
# ['semi_manufactures', ''] 7
# ['fresh_fish', ''] 8
# ['semi_manufactures', ''] 9
# ['canned_food', 'sprats', ''] 11
# ['canned_food', ''] 12
# ['canned_food', 'pate_of_tuna', ''] 13
# ['canned_food', ''] 14
# ['canned_food', 'pate_of_tuna', ''] 15
# ['canned_food', ''] 16
# ['semi_manufactures', ''] 17
# ['caviar', ''] 18
# ['caviar', 'black_caviar', ''] 19
# ['semi_manufactures', ''] 20
# ['frozen_fish', ''] 21
# ['frozen_fish', 'pike', ''] 22
# ['frozen_fish', ''] 23
# ['frozen_fish', 'shark', ''] 24
# ['frozen_fish', ''] 26
# ['success_pay_8642', ''] 28
# ['semi_manufactures', ''] 29
# ['canned_food', 'pate_of_tuna', ''] 33
# ['canned_food', ''] 34
# ['canned_food', ''] 35
# ['fresh_fish', ''] 36
# ['fresh_fish', 'salmon', ''] 37
# ['frozen_fish', ''] 38
# ['fresh_fish', ''] 41
# ['caviar', ''] 43
# ['fresh_fish', 'salmon', ''] 44
# ['semi_manufactures', ''] 46
# ['caviar', ''] 47
# ['canned_food', 'midii', ''] 48
# ['semi_manufactures', 'crab_meat', ''] 49
# ['frozen_fish', ''] 50
# ['canned_food', ''] 51
# ['canned_food', 'pate_of_tuna', ''] 52
# ['fresh_fish', ''] 53
# ['frozen_fish', 'peljad', ''] 54
# ['frozen_fish', ''] 55
# ['fresh_fish', ''] 56
# ['caviar', ''] 57
# ['semi_manufactures', ''] 58
# ['frozen_fish', 'pike', ''] 59
# ['frozen_fish', ''] 60
# ['canned_food', ''] 62
# ['fresh_fish', ''] 64
# ['semi_manufactures', 'crab_meat', ''] 65
# ['canned_food', ''] 66
# ['canned_food', 'sprats', ''] 67
# ['semi_manufactures', ''] 68
# ['frozen_fish', ''] 69
# ['fresh_fish', 'codfish', ''] 70
# ['frozen_fish', ''] 71
# ['semi_manufactures', ''] 72
# ['fresh_fish', ''] 73
# ['fresh_fish', 'crucian', ''] 75
# ['semi_manufactures', ''] 76
# ['semi_manufactures', 'stuffing_eel', ''] 77
# ['frozen_fish', 'shark', ''] 79
# ['fresh_fish', ''] 80
# ['fresh_fish', ''] 81
# ['fresh_fish', ''] 82
# ['semi_manufactures', 'soup_set', ''] 83
# ['semi_manufactures', ''] 84
# ['semi_manufactures', 'crab_meat', ''] 85
# ['caviar', ''] 86
# ['semi_manufactures', ''] 87
# ['fresh_fish', 'codfish', ''] 88
# ['frozen_fish', ''] 89
# ['semi_manufactures', ''] 90
# ['caviar', ''] 91
# ['fresh_fish', 'tuna', ''] 96
# ['canned_food', ''] 97
# ['fresh_fish', ''] 99
# ['caviar', ''] 100
# ['fresh_fish', 'codfish', ''] 102
# ['fresh_fish', ''] 103
# ['fresh_fish', ''] 104
# ['fresh_fish', 'marlene', ''] 105
# ['semi_manufactures', ''] 106
# ['fresh_fish', ''] 108
# ['canned_food', 'pate_of_tuna', ''] 109
# ['canned_food', ''] 110
# ['caviar', ''] 111
# ['fresh_fish', 'herring', ''] 112
# ['fresh_fish', 'marlene', ''] 114
# ['caviar', ''] 115
# ['canned_food', ''] 116
# ['canned_food', 'midii', ''] 119
# ['caviar', ''] 122
# ['frozen_fish', ''] 123
# ['caviar', ''] 124
# ['fresh_fish', ''] 125
# ['semi_manufactures', ''] 126
# ['fresh_fish', ''] 127
# ['semi_manufactures', ''] 128
# ['semi_manufactures', 'squid_rings', ''] 129
# ['caviar', 'squash_caviar', ''] 131
# ['success_pay_8649', ''] 133
# ['canned_food', ''] 134
# ['caviar', ''] 135
# ['caviar', 'black_caviar', ''] 136
# ['semi_manufactures', ''] 137
# ['caviar', ''] 138
# ['fresh_fish', ''] 139
# ['frozen_fish', ''] 140
# ['canned_food', 'sprats', ''] 141
# ['caviar', 'squash_caviar', ''] 142
# ['canned_food', ''] 143
# ['fresh_fish', ''] 144
# ['semi_manufactures', ''] 145
# ['fresh_fish', ''] 146
# ['caviar', ''] 147
# ['frozen_fish', 'peljad', ''] 148
# ['canned_food', ''] 150
# ['fresh_fish', ''] 151
# ['semi_manufactures', ''] 153
# ['semi_manufactures', ''] 154
# ['semi_manufactures', 'stuffing_eel', ''] 155
# ['frozen_fish', ''] 156
# ['fresh_fish', ''] 157
# ['frozen_fish', ''] 158
# ['frozen_fish', 'salmon', ''] 159
# ['success_pay_8646', ''] 161
# ['caviar', ''] 162
# ['caviar', ''] 163
# ['semi_manufactures', ''] 164
# ['caviar', 'red_caviar', ''] 166
# ['fresh_fish', ''] 167
# ['fresh_fish', 'smelt', ''] 168
# ['caviar', ''] 169
# ['caviar', 'squash_caviar', ''] 171
# ['fresh_fish', ''] 172
# ['canned_food', ''] 173
# ['caviar', ''] 174
# ['frozen_fish', ''] 176
# ['frozen_fish', ''] 177
# ['frozen_fish', ''] 179
# ['frozen_fish', 'pike', ''] 180
# ['fresh_fish', ''] 181
# ['success_pay_8643', ''] 184
# ['frozen_fish', ''] 185
# ['success_pay_8648', ''] 188
# ['frozen_fish', 'shark', ''] 189
# ['caviar', ''] 190
# ['semi_manufactures', ''] 191
# ['semi_manufactures', 'soup_set', ''] 192
# ['frozen_fish', ''] 194
# ['frozen_fish', 'peljad', ''] 195
# ['frozen_fish', ''] 196
# ['success_pay_8645', ''] 198
# ['semi_manufactures', ''] 200
# ['semi_manufactures', 'squid_rings', ''] 201
# ['frozen_fish', ''] 203
# ['fresh_fish', ''] 205
# ['canned_food', 'midii', ''] 207
# ['semi_manufactures', ''] 208
# ['semi_manufactures', 'salmon_cutlet', ''] 209
# ['fresh_fish', ''] 211
# ['fresh_fish', 'herring', ''] 212
# ['semi_manufactures', ''] 213
# ['semi_manufactures', 'soup_set', ''] 214
# ['canned_food', ''] 215
# ['canned_food', 'pate_of_tuna', ''] 216
# ['fresh_fish', ''] 217
# ['caviar', ''] 218
# ['fresh_fish', ''] 219
# ['semi_manufactures', ''] 220
# ['semi_manufactures', 'squid_rings', ''] 221
# ['frozen_fish', ''] 222
# ['canned_food', ''] 223
# ['canned_food', 'pate_of_tuna', ''] 224
# ['fresh_fish', ''] 226
# ['semi_manufactures', ''] 228
# ['fresh_fish', ''] 229
# ['caviar', ''] 231
# ['frozen_fish', ''] 233
# ['frozen_fish', 'pike', ''] 234
# ['frozen_fish', ''] 236
# ['frozen_fish', 'pike', ''] 237
# ['canned_food', ''] 238
# ['caviar', ''] 239
# ['caviar', 'squash_caviar', ''] 240
# ['fresh_fish', ''] 243
# ['frozen_fish', ''] 245
# ['semi_manufactures', ''] 246
# ['frozen_fish', 'peljad', ''] 248
# ['semi_manufactures', 'salmon_cutlet', ''] 249
# ['caviar', ''] 250
# ['frozen_fish', ''] 251
# ['frozen_fish', 'pike', ''] 252
# ['frozen_fish', ''] 253
# ['caviar', 'red_caviar', ''] 254
# ['semi_manufactures', ''] 255
# ['fresh_fish', ''] 256
# ['semi_manufactures', 'squid_rings', ''] 257
# ['caviar', ''] 258
# ['semi_manufactures', ''] 259
# ['semi_manufactures', 'squid_rings', ''] 260
# ['caviar', ''] 261
# ['semi_manufactures', ''] 262
# ['frozen_fish', ''] 263
# ['caviar', 'squash_caviar', ''] 264
# ['fresh_fish', ''] 265
# ['frozen_fish', ''] 266
# ['fresh_fish', ''] 267
# ['frozen_fish', ''] 269
# ['frozen_fish', ''] 271
# ['frozen_fish', ''] 272
# ['frozen_fish', 'peljad', ''] 273
# ['fresh_fish', 'crucian', ''] 275
# ['canned_food', ''] 276
# ['fresh_fish', ''] 277
# ['fresh_fish', 'salmon', ''] 278
# ['caviar', ''] 279
# ['success_pay_8653', ''] 282
# ['caviar', ''] 284
# ['caviar', 'squash_caviar', ''] 285
# ['frozen_fish', ''] 287
# ['fresh_fish', ''] 289
# ['frozen_fish', ''] 291
# ['frozen_fish', 'peljad', ''] 292
# ['canned_food', ''] 294
# ['canned_food', 'sprats', ''] 295
# ['canned_food', ''] 296
# ['success_pay_8652', ''] 298
# ['frozen_fish', ''] 299
# ['semi_manufactures', ''] 300
# ['caviar', ''] 301
# ['frozen_fish', ''] 302
# ['semi_manufactures', ''] 303
# ['frozen_fish', ''] 305
# ['frozen_fish', ''] 307
# ['frozen_fish', 'eel', ''] 308
# ['frozen_fish', ''] 310
# ['frozen_fish', ''] 311
# ['frozen_fish', 'pike', ''] 312
# ['frozen_fish', 'peljad', ''] 314
# ['frozen_fish', ''] 315
# ['frozen_fish', 'eel', ''] 316
# ['frozen_fish', ''] 317
# ['frozen_fish', 'peljad', ''] 318
# ['frozen_fish', ''] 319
# ['frozen_fish', 'pike', ''] 320
# ['frozen_fish', ''] 321
# ['frozen_fish', ''] 322
# ['semi_manufactures', ''] 323
# ['frozen_fish', 'pike', ''] 324
# ['frozen_fish', ''] 325
# ['semi_manufactures', 'stuffing_eel', ''] 326
# ['canned_food', ''] 327
# ['canned_food', ''] 328
# ['semi_manufactures', ''] 330
# ['fresh_fish', ''] 331
# ['fresh_fish', 'crucian', ''] 333
# ['caviar', 'squash_caviar', ''] 335
# ['caviar', ''] 336
# ['caviar', 'red_caviar', ''] 337
# ['caviar', ''] 338
# ['fresh_fish', ''] 339
# ['success_pay_8655', ''] 341
# ['canned_food', ''] 343
# ['caviar', ''] 344
# ['caviar', 'black_caviar', ''] 345
# ['caviar', ''] 346
# ['semi_manufactures', ''] 347
# ['semi_manufactures', 'soup_set', ''] 348
# ['semi_manufactures', ''] 350
# ['semi_manufactures', 'squid_rings', ''] 351
# ['success_pay_8657', ''] 353
# ['caviar', ''] 354
# ['caviar', 'squash_caviar', ''] 355
# ['caviar', ''] 356
# ['fresh_fish', ''] 357
# ['caviar', ''] 359
# ['caviar', 'black_caviar', ''] 360
# ['fresh_fish', ''] 362
# ['fresh_fish', 'crucian', ''] 363
# ['success_pay_8658', ''] 365
# ['canned_food', ''] 367
# ['canned_food', 'pate_of_tuna', ''] 368
# ['caviar', ''] 370
# ['caviar', 'black_caviar', ''] 371
# ['caviar', ''] 372
# ['canned_food', ''] 374
# ['semi_manufactures', 'soup_set', ''] 376
# ['frozen_fish', ''] 378
# ['caviar', ''] 380
# ['success_pay_8659', ''] 382
# ['canned_food', ''] 384
# ['semi_manufactures', ''] 386
# ['caviar', ''] 387
# ['frozen_fish', ''] 388
# ['caviar', 'red_caviar', ''] 389
# ['canned_food', ''] 390
# ['canned_food', 'pate_of_tuna', ''] 391
# ['frozen_fish', 'peljad', ''] 392
# ['canned_food', 'pate_of_tuna', ''] 393
# ['frozen_fish', ''] 394
# ['frozen_fish', 'salmon', ''] 395
# ['fresh_fish', ''] 396
# ['frozen_fish', ''] 397
# ['frozen_fish', 'shark', ''] 398
# ['fresh_fish', 'crucian', ''] 399
# ['canned_food', ''] 400
# ['fresh_fish', ''] 401
# ['frozen_fish', ''] 402
# ['fresh_fish', 'marlene', ''] 403
# ['fresh_fish', ''] 405
# ['fresh_fish', ''] 407
# ['frozen_fish', ''] 408
# ['frozen_fish', ''] 409
# ['frozen_fish', 'carp', ''] 410
# ['frozen_fish', 'shark', ''] 411
# ['frozen_fish', ''] 412
# ['caviar', ''] 413
# ['frozen_fish', ''] 414
# ['fresh_fish', ''] 415
# ['fresh_fish', ''] 416
# ['caviar', 'black_caviar', ''] 417
# ['fresh_fish', 'marlene', ''] 419
# ['caviar', ''] 420
# ['fresh_fish', ''] 421
# ['fresh_fish', ''] 422
# ['frozen_fish', ''] 423
# ['frozen_fish', 'pike', ''] 424
# ['canned_food', ''] 425
# ['canned_food', 'pate_of_tuna', ''] 426
# ['canned_food', ''] 427
# ['canned_food', ''] 429
# ['fresh_fish', ''] 432
# ['semi_manufactures', ''] 433
# ['canned_food', 'pate_of_tuna', ''] 434
# ['fresh_fish', 'tuna', ''] 435
# ['semi_manufactures', ''] 437
# ['caviar', ''] 438
# ['caviar', 'red_caviar', ''] 439
# ['canned_food', ''] 440
# ['caviar', ''] 441
# ['caviar', ''] 442
# ['canned_food', ''] 443
# ['canned_food', 'midii', ''] 444
# ['semi_manufactures', ''] 445
# ['canned_food', 'pate_of_tuna', ''] 446
# ['canned_food', ''] 447
# ['semi_manufactures', 'squid_rings', ''] 448
# ['canned_food', 'midii', ''] 449
# ['caviar', ''] 450
# ['caviar', ''] 451
# ['caviar', 'black_caviar', ''] 452
# ['frozen_fish', ''] 453
# ['canned_food', ''] 454
# ['caviar', ''] 455
# ['frozen_fish', ''] 456
# ['frozen_fish', 'eel', ''] 457
# ['frozen_fish', ''] 458
# ['frozen_fish', 'peljad', ''] 459
# ['frozen_fish', 'peljad', ''] 460
# ['frozen_fish', ''] 461
# ['canned_food', ''] 462
# ['canned_food', 'pate_of_tuna', ''] 463
# ['success_pay_8664', ''] 465
# ['caviar', ''] 466
# ['canned_food', ''] 467
# ['frozen_fish', ''] 468
# ['frozen_fish', 'salmon', ''] 469
# ['canned_food', 'midii', ''] 470
# ['canned_food', ''] 471
# ['canned_food', ''] 473
# ['canned_food', ''] 475
# ['frozen_fish', ''] 476
# ['frozen_fish', ''] 477
# ['caviar', ''] 478
# ['caviar', 'red_caviar', ''] 479
# ['frozen_fish', 'carp', ''] 480
# ['frozen_fish', ''] 481
# ['caviar', ''] 482
# ['caviar', 'squash_caviar', ''] 483
# ['caviar', ''] 484
# ['caviar', 'squash_caviar', ''] 485
# ['frozen_fish', 'shark', ''] 486
# ['frozen_fish', ''] 487
# ['caviar', ''] 488
# ['frozen_fish', 'pike', ''] 489
# ['frozen_fish', ''] 490
# ['semi_manufactures', ''] 493
# ['canned_food', 'sprats', ''] 495
# ['canned_food', ''] 496
# ['canned_food', 'midii', ''] 497
# ['frozen_fish', ''] 500
# ['fresh_fish', ''] 501
# ['canned_food', ''] 502
# ['canned_food', 'sprats', ''] 503
# ['canned_food', ''] 504
# ['semi_manufactures', ''] 505
# ['success_pay_8666', ''] 508
# ['canned_food', ''] 509
# ['caviar', ''] 510
# ['canned_food', ''] 511
# ['caviar', ''] 513
# ['caviar', 'squash_caviar', ''] 514
# ['caviar', ''] 515
# ['caviar', 'red_caviar', ''] 516
# ['semi_manufactures', ''] 517
# ['semi_manufactures', ''] 519
# ['canned_food', ''] 520
# ['canned_food', 'sprats', ''] 521
# ['canned_food', ''] 522
# ['semi_manufactures', ''] 523
# ['semi_manufactures', ''] 525
# ['caviar', ''] 527
# ['frozen_fish', ''] 528
# ['frozen_fish', 'salmon', ''] 529
# ['canned_food', ''] 531
# ['canned_food', 'midii', ''] 532
# ['canned_food', ''] 533
# ['canned_food', 'pate_of_tuna', ''] 535
# ['canned_food', ''] 536
# ['frozen_fish', ''] 537
# ['frozen_fish', 'pike', ''] 538
# ['canned_food', ''] 540
# ['canned_food', ''] 541
# ['canned_food', 'midii', ''] 542
# ['canned_food', ''] 543
# ['frozen_fish', ''] 545
# ['frozen_fish', 'peljad', ''] 546
# ['canned_food', 'midii', ''] 547
# ['frozen_fish', ''] 548
# ['canned_food', ''] 550
# ['canned_food', 'midii', ''] 551
# ['fresh_fish', ''] 553
# ['fresh_fish', 'crucian', ''] 554
# ['canned_food', ''] 555
# ['fresh_fish', ''] 556
# ['semi_manufactures', ''] 557
# ['canned_food', 'midii', ''] 558
# ['semi_manufactures', 'stuffing_eel', ''] 559
# ['fresh_fish', ''] 562
# ['caviar', ''] 563
# ['caviar', 'squash_caviar', ''] 564
# ['success_pay_8669', ''] 566
# ['fresh_fish', 'marlene', ''] 567
# ['fresh_fish', ''] 568
# ['frozen_fish', ''] 570
# ['semi_manufactures', 'soup_set', ''] 572
# ['success_pay_8670', ''] 574
# ['semi_manufactures', 'soup_set', ''] 575
# ['canned_food', ''] 576
# ['fresh_fish', ''] 578
# ['canned_food', ''] 579
# ['fresh_fish', 'herring', ''] 580
# ['canned_food', 'pate_of_tuna', ''] 581
# ['semi_manufactures', 'soup_set', ''] 584
# ['semi_manufactures', ''] 585
# ['frozen_fish', ''] 586
# ['caviar', ''] 588
# ['fresh_fish', ''] 590
# ['frozen_fish', ''] 591
# ['frozen_fish', ''] 592
# ['frozen_fish', 'shark', ''] 593
# ['frozen_fish', ''] 594
# ['fresh_fish', ''] 595
# ['fresh_fish', ''] 597
# ['canned_food', ''] 599
# ['frozen_fish', 'carp', ''] 600
# ['fresh_fish', ''] 602
# ['frozen_fish', ''] 604
# ['canned_food', ''] 605
# ['fresh_fish', ''] 606
# ['fresh_fish', 'smelt', ''] 607
# ['frozen_fish', ''] 608
# ['success_pay_8672', ''] 610
# ['canned_food', 'sprats', ''] 611
# ['canned_food', ''] 612
# ['canned_food', 'pate_of_tuna', ''] 613
# ['semi_manufactures', ''] 615
# ['semi_manufactures', 'soup_set', ''] 616
# ['fresh_fish', ''] 617
# ['semi_manufactures', ''] 618
# ['fresh_fish', ''] 619
# ['fresh_fish', 'marlene', ''] 620
# ['fresh_fish', ''] 621
# ['canned_food', ''] 622
# ['canned_food', 'pate_of_tuna', ''] 623
# ['caviar', ''] 625
# ['canned_food', 'midii', ''] 627
# ['fresh_fish', ''] 629
# ['semi_manufactures', ''] 631
# ['canned_food', ''] 633
# ['canned_food', 'midii', ''] 634
# ['caviar', ''] 636
# ['semi_manufactures', ''] 638
# ['canned_food', ''] 640
# ['caviar', ''] 642
# ['caviar', 'squash_caviar', ''] 643
# ['fresh_fish', ''] 644
# ['fresh_fish', 'herring', ''] 645
# ['fresh_fish', ''] 646
# ['fresh_fish', 'marlene', ''] 647
# ['success_pay_8674', ''] 649
# ['canned_food', 'midii', ''] 651
# ['canned_food', ''] 653
# ['canned_food', 'pate_of_tuna', ''] 654
# ['canned_food', ''] 655
# ['fresh_fish', ''] 657
# ['fresh_fish', 'codfish', ''] 658
# ['frozen_fish', ''] 660
# ['semi_manufactures', ''] 661
# ['semi_manufactures', 'stuffing_eel', ''] 662
# ['canned_food', ''] 663
# ['canned_food', 'sprats', ''] 664
# ['canned_food', ''] 665
# ['semi_manufactures', ''] 666
# ['semi_manufactures', 'squid_rings', ''] 667
# ['semi_manufactures', ''] 668
# ['semi_manufactures', 'salmon_cutlet', ''] 669
# ['semi_manufactures', ''] 670
# ['semi_manufactures', 'crab_meat', ''] 671
# ['success_pay_8675', ''] 673
# ['semi_manufactures', ''] 675
# ['frozen_fish', ''] 677
# ['frozen_fish', 'peljad', ''] 678
# ['frozen_fish', ''] 679
# ['fresh_fish', ''] 681
# ['canned_food', ''] 682
# ['canned_food', 'sprats', ''] 683
# ['canned_food', ''] 684
# ['frozen_fish', ''] 685
# ['frozen_fish', 'carp', ''] 686
# ['canned_food', ''] 688
# ['semi_manufactures', ''] 690
# ['semi_manufactures', 'stuffing_eel', ''] 691
# ['fresh_fish', ''] 694
# ['canned_food', ''] 695
# ['semi_manufactures', ''] 696
# ['semi_manufactures', 'stuffing_eel', ''] 697
# ['canned_food', ''] 699
# ['canned_food', 'pate_of_tuna', ''] 700
# ['fresh_fish', ''] 702
# ['fresh_fish', 'smelt', ''] 703
# ['canned_food', ''] 704
# ['canned_food', 'pate_of_tuna', ''] 705
# ['canned_food', ''] 706
# ['success_pay_8677', ''] 708
# ['semi_manufactures', ''] 710
# ['canned_food', ''] 711
# ['canned_food', ''] 713
# ['canned_food', 'midii', ''] 714
# ['canned_food', ''] 716
# ['frozen_fish', ''] 717
# ['frozen_fish', 'peljad', ''] 718
# ['frozen_fish', ''] 719
# ['semi_manufactures', ''] 720
# ['frozen_fish', ''] 721
# ['frozen_fish', 'salmon', ''] 722
# ['frozen_fish', ''] 724
# ['semi_manufactures', ''] 725
# ['canned_food', ''] 726
# ['semi_manufactures', ''] 728
# ['semi_manufactures', 'stuffing_eel', ''] 729
# ['canned_food', ''] 730
# ['canned_food', 'midii', ''] 731
# ['canned_food', ''] 732
# ['canned_food', 'pate_of_tuna', ''] 733
# ['canned_food', ''] 734
# ['semi_manufactures', ''] 735
# ['semi_manufactures', 'squid_rings', ''] 737
# ['success_pay_8678', ''] 739
# ['semi_manufactures', ''] 741
# ['frozen_fish', ''] 743
# ['semi_manufactures', ''] 744
# ['semi_manufactures', 'crab_meat', ''] 745
# ['frozen_fish', 'carp', ''] 746
# ['fresh_fish', ''] 748
# ['fresh_fish', 'tuna', ''] 749
# ['canned_food', ''] 750
# ['semi_manufactures', ''] 751
# ['caviar', ''] 752
# ['canned_food', 'pate_of_tuna', ''] 753
# ['canned_food', ''] 754
# ['canned_food', 'pate_of_tuna', ''] 755
# ['semi_manufactures', ''] 756
# ['semi_manufactures', 'crab_meat', ''] 757
# ['fresh_fish', 'salmon', ''] 760
# ['semi_manufactures', ''] 761
# ['fresh_fish', ''] 763
# ['fresh_fish', 'marlene', ''] 764
# ['semi_manufactures', ''] 766
# ['semi_manufactures', ''] 767
# ['caviar', ''] 769
# ['caviar', 'squash_caviar', ''] 770
# ['canned_food', 'midii', ''] 772
# ['canned_food', ''] 773
# ['success_pay_8680', ''] 775
# ['fresh_fish', ''] 777
# ['fresh_fish', 'herring', ''] 778
# ['fresh_fish', ''] 779
# ['fresh_fish', ''] 780
# ['fresh_fish', ''] 782
# ['fresh_fish', 'tuna', ''] 783
# ['frozen_fish', ''] 785
# ['frozen_fish', 'carp', ''] 786
# ['semi_manufactures', ''] 787
# ['fresh_fish', ''] 788
# ['semi_manufactures', ''] 791
# ['fresh_fish', 'crucian', ''] 792
# ['fresh_fish', ''] 793
# ['semi_manufactures', 'crab_meat', ''] 795
# ['semi_manufactures', ''] 797
# ['frozen_fish', ''] 799
# ['semi_manufactures', ''] 800
# ['caviar', ''] 801
# ['canned_food', ''] 802
# ['fresh_fish', ''] 803
# ['caviar', ''] 805
# ['canned_food', ''] 806
# ['caviar', ''] 807
# ['caviar', 'black_caviar', ''] 808
# ['fresh_fish', ''] 809
# ['canned_food', ''] 810
# ['caviar', ''] 811
# ['canned_food', ''] 813
# ['canned_food', 'sprats', ''] 814
# ['canned_food', 'sprats', ''] 815
# ['canned_food', ''] 816
# ['caviar', ''] 817
# ['caviar', 'black_caviar', ''] 818
# ['fresh_fish', ''] 820
# ['fresh_fish', ''] 821
# ['fresh_fish', 'crucian', ''] 822
# ['fresh_fish', 'crucian', ''] 824
# ['semi_manufactures', ''] 825
# ['frozen_fish', ''] 827
# ['fresh_fish', ''] 828
# ['fresh_fish', 'tuna', ''] 829
# ['frozen_fish', ''] 831
# ['frozen_fish', 'shark', ''] 832
# ['success_pay_8681', ''] 834
# ['fresh_fish', ''] 836
# ['fresh_fish', ''] 838
# ['caviar', ''] 840
# ['frozen_fish', ''] 841
# ['frozen_fish', 'eel', ''] 842
# ['frozen_fish', ''] 843
# ['fresh_fish', ''] 844
# ['fresh_fish', ''] 846
# ['fresh_fish', 'salmon', ''] 847
# ['semi_manufactures', ''] 849
# ['semi_manufactures', 'crab_meat', ''] 850
# ['semi_manufactures', ''] 851
# ['semi_manufactures', 'stuffing_eel', ''] 852
# ['frozen_fish', ''] 854
# ['success_pay_8684', ''] 857
# ['caviar', ''] 859
# ['caviar', 'red_caviar', ''] 860
# ['canned_food', ''] 863
# ['frozen_fish', ''] 864
# ['frozen_fish', 'eel', ''] 866
# ['fresh_fish', ''] 867
# ['canned_food', 'sprats', ''] 868
# ['canned_food', ''] 869
# ['fresh_fish', ''] 870
# ['frozen_fish', ''] 871
# ['frozen_fish', ''] 873
# ['semi_manufactures', ''] 874
# ['semi_manufactures', 'stuffing_eel', ''] 875
# ['semi_manufactures', ''] 876
# ['fresh_fish', ''] 877
# ['fresh_fish', 'salmon', ''] 878
# ['caviar', ''] 879
# ['fresh_fish', ''] 880
# ['fresh_fish', 'smelt', ''] 881
# ['semi_manufactures', ''] 882
# ['canned_food', ''] 883
# ['canned_food', 'midii', ''] 884
# ['semi_manufactures', 'stuffing_eel', ''] 885
# ['canned_food', ''] 886
# ['semi_manufactures', ''] 888
# ['canned_food', ''] 889
# ['semi_manufactures', 'stuffing_eel', ''] 891
# ['caviar', ''] 893
# ['fresh_fish', ''] 894
# ['fresh_fish', ''] 896
# ['caviar', ''] 897
# ['fresh_fish', 'tuna', ''] 898
# ['semi_manufactures', ''] 899
# ['caviar', ''] 900
# ['caviar', 'squash_caviar', ''] 901
# ['fresh_fish', ''] 902
# ['caviar', 'squash_caviar', ''] 903
# ['canned_food', ''] 904
# ['caviar', ''] 905
# ['caviar', ''] 906
# ['semi_manufactures', ''] 907
# ['caviar', 'black_caviar', ''] 908
# ['fresh_fish', ''] 910
# ['fresh_fish', 'smelt', ''] 911
# ['frozen_fish', ''] 913
# ['frozen_fish', ''] 915
# ['frozen_fish', 'salmon', ''] 916
# ['frozen_fish', ''] 917
# ['semi_manufactures', ''] 919
# ['success_pay_8686', ''] 921
# ['semi_manufactures', 'salmon_cutlet', ''] 922
# ['fresh_fish', ''] 924
# ['frozen_fish', 'eel', ''] 926
# ['canned_food', ''] 927
# ['frozen_fish', 'salmon', ''] 929
# ['canned_food', ''] 931
# ['frozen_fish', ''] 932
# ['canned_food', 'sprats', ''] 933
# ['fresh_fish', ''] 934
# ['frozen_fish', ''] 935
# ['frozen_fish', 'shark', ''] 936
# ['frozen_fish', ''] 937
# ['semi_manufactures', ''] 938
# ['frozen_fish', ''] 940
# ['frozen_fish', 'carp', ''] 942
# ['frozen_fish', 'peljad', ''] 943
# ['fresh_fish', 'marlene', ''] 944
# ['canned_food', ''] 945
# ['semi_manufactures', ''] 946
# ['canned_food', 'sprats', ''] 948
# ['frozen_fish', 'eel', ''] 949
# ['caviar', ''] 952
# ['caviar', ''] 953
# ['fresh_fish', ''] 954
# ['frozen_fish', ''] 956
# ['caviar', 'black_caviar', ''] 957
# ['caviar', ''] 958
# ['frozen_fish', ''] 961
# ['caviar', ''] 962
# ['caviar', ''] 964
# ['caviar', 'red_caviar', ''] 965
# ['caviar', ''] 966
# ['fresh_fish', ''] 967
# ['caviar', 'squash_caviar', ''] 968
# ['canned_food', ''] 969
# ['caviar', 'black_caviar', ''] 970
# ['caviar', ''] 971
# ['caviar', 'squash_caviar', ''] 972
# ['canned_food', ''] 974
# ['success_pay_8693', ''] 976
# ['fresh_fish', 'salmon', ''] 978
# ['canned_food', ''] 980
# ['fresh_fish', 'codfish', ''] 981
# ['caviar', ''] 984
# ['caviar', 'squash_caviar', ''] 986
# ['canned_food', ''] 987
# ['canned_food', ''] 988
# ['success_pay_8689', ''] 990
# ['canned_food', 'midii', ''] 991
# ['caviar', 'squash_caviar', ''] 992
# ['caviar', ''] 993
# ['canned_food', 'midii', ''] 995
# ['canned_food', ''] 996
# ['caviar', ''] 997
# ['semi_manufactures', ''] 999
# ['canned_food', 'sprats', ''] 1000
# ['semi_manufactures', 'salmon_cutlet', ''] 1001
# ['semi_manufactures', ''] 1002
# ['semi_manufactures', 'soup_set', ''] 1003
# ['canned_food', ''] 1004
# ['caviar', ''] 1005
# ['canned_food', 'sprats', ''] 1007
# ['frozen_fish', 'pike', ''] 1008
# ['canned_food', ''] 1010
# ['frozen_fish', ''] 1011
# ['canned_food', ''] 1012
# ['canned_food', 'midii', ''] 1013
# ['caviar', ''] 1015
# ['frozen_fish', ''] 1016
# ['canned_food', ''] 1017
# ['canned_food', ''] 1018
# ['semi_manufactures', ''] 1019
# ['semi_manufactures', 'crab_meat', ''] 1020
# ['canned_food', 'pate_of_tuna', ''] 1022
# ['caviar', ''] 1023
# ['canned_food', 'sprats', ''] 1024
# ['canned_food', ''] 1025
# ['fresh_fish', ''] 1026
# ['success_pay_8691', ''] 1028
# ['caviar', ''] 1029
# ['caviar', 'black_caviar', ''] 1030
# ['success_pay_8692', ''] 1032
# ['caviar', 'black_caviar', ''] 1033
# ['fresh_fish', ''] 1034
# ['fresh_fish', 'codfish', ''] 1035
# ['caviar', ''] 1036
# ['fresh_fish', ''] 1038
# ['canned_food', ''] 1040
# ['fresh_fish', 'crucian', ''] 1041
# ['frozen_fish', ''] 1048
# ['fresh_fish', ''] 1049
# ['fresh_fish', ''] 1050
# ['frozen_fish', 'peljad', ''] 1052
# ['caviar', 'red_caviar', ''] 1053
# ['canned_food', ''] 1054
# ['canned_food', ''] 1055
# ['fresh_fish', 'salmon', ''] 1056
# ['canned_food', 'midii', ''] 1057
# ['caviar', ''] 1059
# ['fresh_fish', ''] 1060
# ['fresh_fish', ''] 1061
# ['caviar', ''] 1062
# ['fresh_fish', 'marlene', ''] 1063
# ['semi_manufactures', ''] 1064
# ['caviar', 'squash_caviar', ''] 1065
# ['canned_food', ''] 1066
# ['caviar', ''] 1069
# ['semi_manufactures', ''] 1071
# ['fresh_fish', ''] 1072
# ['frozen_fish', 'eel', ''] 1073
# ['frozen_fish', ''] 1074
# ['canned_food', ''] 1075
# ['frozen_fish', ''] 1076
# ['semi_manufactures', 'soup_set', ''] 1077
# ['caviar', 'black_caviar', ''] 1078
# ['fresh_fish', ''] 1079
# ['caviar', ''] 1080
# ['semi_manufactures', ''] 1081
# ['fresh_fish', ''] 1083
# ['fresh_fish', ''] 1085
# ['fresh_fish', 'smelt', ''] 1086
# ['frozen_fish', 'carp', ''] 1088
# ['canned_food', ''] 1089
# ['fresh_fish', 'tuna', ''] 1090
# ['semi_manufactures', ''] 1091
# ['caviar', 'black_caviar', ''] 1092
# ['canned_food', ''] 1093
# ['caviar', ''] 1095
# ['semi_manufactures', ''] 1097
# ['canned_food', 'pate_of_tuna', ''] 1098
# ['frozen_fish', ''] 1100
# ['frozen_fish', ''] 1101
# ['semi_manufactures', 'stuffing_eel', ''] 1102
# ['semi_manufactures', ''] 1103
# ['caviar', ''] 1104
# ['fresh_fish', ''] 1106
# ['frozen_fish', 'salmon', ''] 1107
# ['semi_manufactures', 'squid_rings', ''] 1110
# ['canned_food', 'pate_of_tuna', ''] 1111
# ['frozen_fish', 'carp', ''] 1112
# ['fresh_fish', ''] 1113
# ['semi_manufactures', ''] 1114
# ['caviar', ''] 1115
# ['semi_manufactures', ''] 1116
# ['fresh_fish', ''] 1117
# ['fresh_fish', 'marlene', ''] 1118
# ['semi_manufactures', ''] 1119
# ['fresh_fish', 'salmon', ''] 1121
# ['semi_manufactures', ''] 1122
# ['canned_food', ''] 1123
# ['semi_manufactures', 'crab_meat', ''] 1125
# ['fresh_fish', 'salmon', ''] 1128
# ['caviar', ''] 1130
# ['frozen_fish', ''] 1131
# ['frozen_fish', ''] 1132
# ['caviar', ''] 1133
# ['frozen_fish', 'shark', ''] 1135
# ['caviar', 'black_caviar', ''] 1137
# ['caviar', 'black_caviar', ''] 1138
# ['frozen_fish', ''] 1139
# ['canned_food', ''] 1140
# ['canned_food', ''] 1143
# ['semi_manufactures', 'stuffing_eel', ''] 1144
# ['semi_manufactures', ''] 1145
# ['frozen_fish', ''] 1146
# ['canned_food', ''] 1147
# ['canned_food', ''] 1148
# ['canned_food', 'midii', ''] 1150
# ['semi_manufactures', ''] 1151
# ['canned_food', ''] 1152
# ['canned_food', ''] 1153
# ['caviar', ''] 1154
# ['canned_food', ''] 1155
# ['success_pay_8698', ''] 1158
# ['caviar', 'red_caviar', ''] 1159
# ['canned_food', ''] 1160
# ['frozen_fish', ''] 1161
# ['caviar', ''] 1162
# ['fresh_fish', ''] 1163
# ['caviar', ''] 1164
# ['canned_food', 'sprats', ''] 1165
# ['frozen_fish', 'salmon', ''] 1167
# ['frozen_fish', ''] 1168
# ['caviar', 'red_caviar', ''] 1169
# ['frozen_fish', 'carp', ''] 1170
# ['frozen_fish', ''] 1171
# ['fresh_fish', 'smelt', ''] 1173
# ['canned_food', 'pate_of_tuna', ''] 1174
# ['caviar', ''] 1176
# ['canned_food', 'midii', ''] 1178
# ['caviar', ''] 1179
# ['semi_manufactures', ''] 1182
# ['semi_manufactures', 'salmon_cutlet', ''] 1183
# ['caviar', 'red_caviar', ''] 1184
# ['semi_manufactures', ''] 1185
# ['success_pay_8700', ''] 1187
# ['semi_manufactures', 'crab_meat', ''] 1188
# ['caviar', ''] 1190
# ['frozen_fish', ''] 1191
# ['frozen_fish', 'shark', ''] 1192
# ['fresh_fish', ''] 1193
# ['fresh_fish', 'tuna', ''] 1194
# ['semi_manufactures', ''] 1195
# ['semi_manufactures', 'stuffing_eel', ''] 1196
# ['semi_manufactures', ''] 1197
# ['fresh_fish', ''] 1199
# ['success_pay_8699', ''] 1201
# ['semi_manufactures', 'soup_set', ''] 1202
# ['success_pay_8697', ''] 1204
# ['caviar', ''] 1206
# ['success_pay_8702', ''] 1208
# ['canned_food', 'pate_of_tuna', ''] 1209
# ['success_pay_8695', ''] 1211
# ['canned_food', ''] 1212
# ['caviar', ''] 1213
# ['caviar', ''] 1214
# ['caviar', 'squash_caviar', ''] 1215
# ['caviar', ''] 1216
# ['semi_manufactures', ''] 1217
# ['semi_manufactures', 'stuffing_eel', ''] 1219
# ['fresh_fish', ''] 1220
# ['fresh_fish', ''] 1221
# ['fresh_fish', 'herring', ''] 1222
# ['fresh_fish', 'salmon', ''] 1223
# ['canned_food', ''] 1224
# ['fresh_fish', ''] 1225
# ['semi_manufactures', ''] 1227
# ['success_pay_8696', ''] 1229
# ['fresh_fish', ''] 1230
# ['fresh_fish', 'smelt', ''] 1231
# ['fresh_fish', ''] 1232
# ['semi_manufactures', ''] 1233
# ['success_pay_8701', ''] 1235
# ['frozen_fish', 'carp', ''] 1236
# ['caviar', ''] 1238
# ['canned_food', ''] 1239
# ['fresh_fish', ''] 1240
# ['semi_manufactures', ''] 1241
# ['fresh_fish', 'marlene', ''] 1243
# ['frozen_fish', ''] 1245
# ['semi_manufactures', ''] 1246
# ['semi_manufactures', ''] 1247
# ['canned_food', ''] 1249
# ['semi_manufactures', ''] 1250
# ['fresh_fish', 'herring', ''] 1251
# ['semi_manufactures', 'soup_set', ''] 1253
# ['caviar', ''] 1254
# ['semi_manufactures', ''] 1255
# ['fresh_fish', ''] 1256
# ['semi_manufactures', ''] 1257
# ['semi_manufactures', ''] 1258
# ['fresh_fish', ''] 1260
# ['canned_food', ''] 1261
# ['fresh_fish', 'codfish', ''] 1262
# ['success_pay_8705', ''] 1264
# ['semi_manufactures', 'squid_rings', ''] 1265
# ['fresh_fish', 'tuna', ''] 1267
# ['canned_food', 'midii', ''] 1268
# ['canned_food', ''] 1269
# ['caviar', ''] 1271
# ['fresh_fish', ''] 1272
# ['fresh_fish', ''] 1273
# ['fresh_fish', 'marlene', ''] 1274
# ['fresh_fish', ''] 1275
# ['caviar', ''] 1277
# ['semi_manufactures', ''] 1279
# ['success_pay_8706', ''] 1281
# ['fresh_fish', 'marlene', ''] 1282
# ['fresh_fish', ''] 1283
# ['caviar', ''] 1284
# ['semi_manufactures', ''] 1286
# ['frozen_fish', ''] 1288
# ['frozen_fish', 'eel', ''] 1289
# ['frozen_fish', ''] 1290
# ['frozen_fish', ''] 1292
# ['frozen_fish', 'eel', ''] 1293
# ['frozen_fish', ''] 1294
# ['frozen_fish', 'pike', ''] 1295
# ['frozen_fish', ''] 1296
# ['frozen_fish', 'peljad', ''] 1297
# ['frozen_fish', ''] 1298
# ['frozen_fish', 'salmon', ''] 1299
# ['frozen_fish', ''] 1300
# ['caviar', ''] 1301
# ['caviar', 'black_caviar', ''] 1302
# ['semi_manufactures', ''] 1303
# ['frozen_fish', ''] 1305
# ['semi_manufactures', ''] 1307
# ['semi_manufactures', ''] 1310
# ['canned_food', ''] 1313
# ['fresh_fish', ''] 1314
# ['frozen_fish', ''] 1315
# ['semi_manufactures', ''] 1316
# ['frozen_fish', ''] 1317
# ['caviar', ''] 1318
# ['semi_manufactures', ''] 1320
# ['frozen_fish', ''] 1321
# ['canned_food', 'midii', ''] 1322
# ['canned_food', ''] 1323
# ['semi_manufactures', 'stuffing_eel', ''] 1324
# ['fresh_fish', ''] 1326
# ['fresh_fish', 'herring', ''] 1327
# ['fresh_fish', ''] 1329
# ['semi_manufactures', ''] 1330
# ['semi_manufactures', 'squid_rings', ''] 1331
# ['semi_manufactures', ''] 1332
# ['fresh_fish', ''] 1333
# ['fresh_fish', 'codfish', ''] 1334
# ['caviar', ''] 1336
# ['semi_manufactures', 'crab_meat', ''] 1337
# ['semi_manufactures', ''] 1340
# ['fresh_fish', 'smelt', ''] 1341
# ['caviar', ''] 1343
# ['success_pay_8707', ''] 1345
# ['caviar', 'red_caviar', ''] 1346
# ['frozen_fish', ''] 1348
# ['frozen_fish', 'pike', ''] 1349
# ['canned_food', ''] 1350
# ['canned_food', ''] 1351
# ['frozen_fish', ''] 1352
# ['canned_food', 'pate_of_tuna', ''] 1353
# ['canned_food', ''] 1356
# ['frozen_fish', ''] 1357
# ['fresh_fish', ''] 1358
# ['canned_food', ''] 1359
# ['canned_food', 'sprats', ''] 1361
# ['canned_food', ''] 1362
# ['frozen_fish', ''] 1363
# ['canned_food', ''] 1364
# ['fresh_fish', ''] 1365
# ['fresh_fish', 'marlene', ''] 1366
# ['caviar', ''] 1367
# ['frozen_fish', ''] 1368
# ['frozen_fish', 'carp', ''] 1369
# ['semi_manufactures', ''] 1370
# ['success_pay_8708', ''] 1373
# ['frozen_fish', ''] 1374
# ['canned_food', 'sprats', ''] 1375
# ['frozen_fish', 'pike', ''] 1376
# ['canned_food', ''] 1377
# ['canned_food', 'midii', ''] 1379
# ['canned_food', ''] 1381
# ['canned_food', 'sprats', ''] 1382
# ['canned_food', ''] 1383
# ['canned_food', ''] 1384
# ['canned_food', 'sprats', ''] 1385
# ['canned_food', 'midii', ''] 1386
# ['semi_manufactures', ''] 1387
# ['semi_manufactures', 'stuffing_eel', ''] 1388
# ['semi_manufactures', ''] 1389
# ['semi_manufactures', ''] 1391
# ['caviar', ''] 1392
# ['caviar', ''] 1394
# ['semi_manufactures', ''] 1397
# ['canned_food', ''] 1398
# ['fresh_fish', ''] 1399
# ['caviar', 'black_caviar', ''] 1400
# ['fresh_fish', 'crucian', ''] 1401
# ['fresh_fish', ''] 1402
# ['caviar', ''] 1403
# ['fresh_fish', 'smelt', ''] 1404
# ['canned_food', 'midii', ''] 1406
# ['semi_manufactures', 'soup_set', ''] 1407
# ['success_pay_8710', ''] 1409
# ['canned_food', ''] 1410
# ['fresh_fish', ''] 1412
# ['success_pay_8711', ''] 1414
# ['fresh_fish', ''] 1415
# ['fresh_fish', 'crucian', ''] 1416
# ['fresh_fish', ''] 1417
# ['success_pay_8709', ''] 1419
# ['canned_food', ''] 1421
# ['fresh_fish', ''] 1424
# ['canned_food', ''] 1426
# ['caviar', ''] 1427
# ['fresh_fish', ''] 1428
# ['caviar', ''] 1431
# ['canned_food', 'sprats', ''] 1432
# ['canned_food', ''] 1434
# ['fresh_fish', 'tuna', ''] 1435
# ['fresh_fish', ''] 1436
# ['fresh_fish', ''] 1437
# ['caviar', 'red_caviar', ''] 1438
# ['semi_manufactures', ''] 1440
# ['caviar', ''] 1441
# ['caviar', ''] 1442
# ['frozen_fish', ''] 1443
# ['caviar', 'squash_caviar', ''] 1445
# ['canned_food', ''] 1446
# ['frozen_fish', ''] 1450
# ['semi_manufactures', ''] 1451
# ['canned_food', 'sprats', ''] 1452
# ['semi_manufactures', 'stuffing_eel', ''] 1454
# ['caviar', 'black_caviar', ''] 1455
# ['frozen_fish', 'pike', ''] 1456
# ['canned_food', 'pate_of_tuna', ''] 1457
# ['canned_food', ''] 1458
# ['frozen_fish', ''] 1461
# ['frozen_fish', 'shark', ''] 1462
# ['canned_food', ''] 1463
# ['semi_manufactures', ''] 1464
# ['frozen_fish', ''] 1466
# ['frozen_fish', ''] 1468
# ['frozen_fish', 'carp', ''] 1469
# ['canned_food', ''] 1470
# ['semi_manufactures', 'soup_set', ''] 1471
# ['semi_manufactures', ''] 1472
# ['semi_manufactures', ''] 1473
# ['frozen_fish', 'shark', ''] 1475
# ['semi_manufactures', ''] 1476
# ['frozen_fish', ''] 1477
# ['semi_manufactures', 'soup_set', ''] 1479
# ['canned_food', ''] 1481
# ['semi_manufactures', ''] 1482
# ['semi_manufactures', ''] 1484
# ['semi_manufactures', ''] 1486
# ['frozen_fish', ''] 1488
# ['frozen_fish', 'pike', ''] 1489
# ['semi_manufactures', 'salmon_cutlet', ''] 1490
# ['frozen_fish', 'salmon', ''] 1491
# ['semi_manufactures', 'squid_rings', ''] 1492
# ['success_pay_8719', ''] 1494
# ['semi_manufactures', ''] 1496
# ['frozen_fish', ''] 1497
# ['caviar', ''] 1498
# ['frozen_fish', 'pike', ''] 1499
# ['semi_manufactures', 'crab_meat', ''] 1500
# ['caviar', ''] 1501
# ['frozen_fish', 'salmon', ''] 1502
# ['canned_food', 'pate_of_tuna', ''] 1503
# ['fresh_fish', ''] 1504
# ['caviar', 'black_caviar', ''] 1506
# ['semi_manufactures', 'soup_set', ''] 1507
# ['semi_manufactures', ''] 1508
# ['caviar', ''] 1509
# ['caviar', 'squash_caviar', ''] 1512
# ['semi_manufactures', 'squid_rings', ''] 1513
# ['fresh_fish', ''] 1514
# ['caviar', ''] 1515
# ['caviar', ''] 1516
# ['semi_manufactures', ''] 1517
# ['caviar', 'black_caviar', ''] 1520
# ['frozen_fish', ''] 1521
# ['fresh_fish', ''] 1522
# ['canned_food', ''] 1523
# ['caviar', ''] 1524
# ['canned_food', ''] 1525
# ['frozen_fish', ''] 1527
# ['canned_food', 'midii', ''] 1528
# ['semi_manufactures', ''] 1529
# ['semi_manufactures', ''] 1530
# ['fresh_fish', 'marlene', ''] 1531
# ['fresh_fish', ''] 1532
# ['frozen_fish', 'shark', ''] 1533
# ['semi_manufactures', 'soup_set', ''] 1534
# ['canned_food', ''] 1536
# ['fresh_fish', 'herring', ''] 1537
# ['canned_food', ''] 1538
# ['caviar', ''] 1539
# ['caviar', 'red_caviar', ''] 1540
# ['caviar', ''] 1541
# ['canned_food', 'sprats', ''] 1543
# ['fresh_fish', ''] 1545
# ['success_pay_8714', ''] 1547
# ['frozen_fish', ''] 1548
# ['caviar', 'red_caviar', ''] 1549
# ['caviar', ''] 1551
# ['canned_food', 'sprats', ''] 1552
# ['success_pay_8720', ''] 1554
# ['caviar', ''] 1555
# ['success_pay_8717', ''] 1557
# ['caviar', 'black_caviar', ''] 1559
# ['fresh_fish', ''] 1560
# ['fresh_fish', 'smelt', ''] 1561
# ['canned_food', ''] 1564
# ['semi_manufactures', ''] 1565
# ['caviar', ''] 1566
# ['semi_manufactures', 'squid_rings', ''] 1567
# ['fresh_fish', ''] 1568
# ['fresh_fish', 'salmon', ''] 1569
# ['caviar', 'red_caviar', ''] 1570
# ['fresh_fish', ''] 1571
# ['semi_manufactures', ''] 1572
# ['semi_manufactures', ''] 1573
# ['semi_manufactures', 'stuffing_eel', ''] 1575
# ['semi_manufactures', 'crab_meat', ''] 1577
# ['semi_manufactures', ''] 1578
# ['frozen_fish', ''] 1579
# ['canned_food', ''] 1581
# ['success_pay_8718', ''] 1584
# ['canned_food', ''] 1587
# ['frozen_fish', ''] 1588
# ['caviar', 'red_caviar', ''] 1590
# ['caviar', ''] 1591
# ['caviar', ''] 1593
# ['canned_food', ''] 1594
# ['success_pay_8713', ''] 1596
# ['canned_food', 'midii', ''] 1597
# ['canned_food', ''] 1598
# ['caviar', ''] 1599
# ['semi_manufactures', ''] 1600
# ['canned_food', ''] 1601
# ['canned_food', 'sprats', ''] 1602
# ['canned_food', ''] 1603
# ['caviar', 'black_caviar', ''] 1605
# ['success_pay_8712', ''] 1608
# ['caviar', ''] 1610
# ['frozen_fish', ''] 1612
# ['caviar', ''] 1615
# ['caviar', 'squash_caviar', ''] 1616
# ['canned_food', ''] 1617
# ['semi_manufactures', ''] 1619
# ['caviar', ''] 1620
# ['canned_food', ''] 1621
# ['semi_manufactures', 'salmon_cutlet', ''] 1623
# ['caviar', 'red_caviar', ''] 1625
# ['fresh_fish', ''] 1627
# ['fresh_fish', ''] 1628
# ['semi_manufactures', ''] 1629
# ['fresh_fish', ''] 1630
# ['fresh_fish', 'herring', ''] 1631
# ['fresh_fish', 'salmon', ''] 1633
# ['fresh_fish', ''] 1634
# ['fresh_fish', 'herring', ''] 1635
# ['caviar', ''] 1636
# ['semi_manufactures', ''] 1637
# ['semi_manufactures', 'stuffing_eel', ''] 1638
# ['caviar', ''] 1641
# ['caviar', 'black_caviar', ''] 1642
# ['frozen_fish', ''] 1643
# ['canned_food', ''] 1644
# ['frozen_fish', ''] 1645
# ['frozen_fish', 'salmon', ''] 1647
# ['caviar', ''] 1648
# ['canned_food', ''] 1649
# ['fresh_fish', ''] 1650
# ['fresh_fish', 'tuna', ''] 1651
# ['semi_manufactures', ''] 1653
# ['success_pay_8723', ''] 1655
# ['frozen_fish', ''] 1656
# ['frozen_fish', 'carp', ''] 1657
# ['semi_manufactures', 'soup_set', ''] 1659
# ['semi_manufactures', ''] 1662
# ['canned_food', ''] 1663
# ['caviar', ''] 1665
# ['semi_manufactures', 'soup_set', ''] 1666
# ['caviar', ''] 1667
# ['canned_food', ''] 1668
# ['caviar', 'squash_caviar', ''] 1669
# ['fresh_fish', ''] 1670
# ['semi_manufactures', ''] 1671
# ['fresh_fish', ''] 1674
# ['frozen_fish', 'carp', ''] 1675
# ['fresh_fish', 'codfish', ''] 1676
# ['semi_manufactures', 'squid_rings', ''] 1677
# ['fresh_fish', ''] 1678
# ['fresh_fish', 'smelt', ''] 1679
# ['fresh_fish', ''] 1680
# ['frozen_fish', ''] 1681
# ['fresh_fish', ''] 1682
# ['fresh_fish', 'herring', ''] 1683
# ['canned_food', ''] 1686
# ['caviar', ''] 1688
# ['frozen_fish', ''] 1689
# ['canned_food', 'sprats', ''] 1690
# ['canned_food', ''] 1691
# ['fresh_fish', ''] 1692
# ['frozen_fish', 'peljad', ''] 1693
# ['canned_food', ''] 1694
# ['canned_food', ''] 1695
# ['canned_food', 'pate_of_tuna', ''] 1696
# ['frozen_fish', ''] 1697
# ['frozen_fish', ''] 1700
# ['frozen_fish', 'shark', ''] 1701
# ['frozen_fish', ''] 1702
# ['canned_food', 'pate_of_tuna', ''] 1703
# ['fresh_fish', ''] 1704
# ['frozen_fish', 'pike', ''] 1706
# ['caviar', ''] 1707
# ['success_pay_8727', ''] 1709
# ['canned_food', ''] 1711
# ['canned_food', ''] 1713
# ['canned_food', 'midii', ''] 1714
# ['caviar', 'squash_caviar', ''] 1715
# ['semi_manufactures', ''] 1716
# ['semi_manufactures', 'squid_rings', ''] 1717
# ['canned_food', 'midii', ''] 1719
# ['caviar', ''] 1720
# ['caviar', ''] 1721
# ['caviar', 'black_caviar', ''] 1722
# ['fresh_fish', ''] 1723
# ['success_pay_8724', ''] 1725
# ['fresh_fish', ''] 1727
# ['semi_manufactures', ''] 1728
# ['semi_manufactures', 'squid_rings', ''] 1729
# ['frozen_fish', ''] 1730
# ['fresh_fish', ''] 1732
# ['fresh_fish', 'marlene', ''] 1733
# ['success_pay_8726', ''] 1736
# ['canned_food', ''] 1737
# ['caviar', ''] 1738
# ['canned_food', 'midii', ''] 1739
# ['fresh_fish', ''] 1741
# ['canned_food', ''] 1742
# ['fresh_fish', ''] 1743
# ['fresh_fish', 'tuna', ''] 1744
# ['fresh_fish', ''] 1745
# ['canned_food', ''] 1747
# ['frozen_fish', ''] 1748
# ['frozen_fish', 'peljad', ''] 1749
# ['frozen_fish', ''] 1750
# ['fresh_fish', ''] 1751
# ['caviar', ''] 1753
# ['caviar', 'squash_caviar', ''] 1754
# ['frozen_fish', ''] 1755
# ['caviar', ''] 1756
# ['caviar', ''] 1757
# ['canned_food', ''] 1758
# ['canned_food', 'midii', ''] 1759
# ['canned_food', ''] 1761
# ['canned_food', 'midii', ''] 1762
# ['semi_manufactures', ''] 1764
# ['canned_food', ''] 1765
# ['frozen_fish', ''] 1766
# ['frozen_fish', 'eel', ''] 1767
# ['frozen_fish', ''] 1768
# ['frozen_fish', 'peljad', ''] 1769
# ['frozen_fish', ''] 1770
# ['frozen_fish', 'eel', ''] 1771
# ['frozen_fish', ''] 1772
# ['caviar', ''] 1773
# ['success_pay_8728', ''] 1775
# ['semi_manufactures', ''] 1777
# ['semi_manufactures', 'soup_set', ''] 1778
# ['semi_manufactures', ''] 1780
# ['semi_manufactures', 'crab_meat', ''] 1782
# ['canned_food', 'sprats', ''] 1783
# ['semi_manufactures', ''] 1784
# ['frozen_fish', ''] 1785
# ['frozen_fish', 'peljad', ''] 1786
# ['canned_food', ''] 1788
# ['canned_food', 'sprats', ''] 1790
# ['canned_food', ''] 1791
# ['frozen_fish', ''] 1792
# ['canned_food', ''] 1793
# ['frozen_fish', ''] 1794
# ['frozen_fish', ''] 1796
# ['fresh_fish', ''] 1797
# ['frozen_fish', 'peljad', ''] 1798
# ['frozen_fish', ''] 1799
# ['semi_manufactures', ''] 1800
# ['semi_manufactures', 'soup_set', ''] 1801
# ['frozen_fish', 'salmon', ''] 1802
# ['semi_manufactures', ''] 1803
# ['caviar', ''] 1805
# ['caviar', 'black_caviar', ''] 1806
# ['caviar', ''] 1807
# ['success_pay_8730', ''] 1809
# ['canned_food', 'midii', ''] 1810
# ['semi_manufactures', ''] 1812
# ['caviar', ''] 1814
# ['success_pay_8731', ''] 1816
# ['caviar', ''] 1820
# ['caviar', ''] 1821
# ['caviar', 'red_caviar', ''] 1824
# ['canned_food', ''] 1825
# ['frozen_fish', ''] 1826
# ['canned_food', ''] 1827
# ['semi_manufactures', ''] 1828
# ['semi_manufactures', ''] 1829
# ['frozen_fish', 'salmon', ''] 1831
# ['semi_manufactures', ''] 1832
# ['semi_manufactures', 'soup_set', ''] 1833
# ['fresh_fish', ''] 1834
# ['semi_manufactures', 'crab_meat', ''] 1835
# ['caviar', ''] 1836
# ['semi_manufactures', ''] 1837
# ['caviar', 'squash_caviar', ''] 1838
# ['semi_manufactures', 'crab_meat', ''] 1839
# ['semi_manufactures', 'crab_meat', ''] 1841
# ['canned_food', ''] 1843
# ['semi_manufactures', ''] 1844
# ['canned_food', 'sprats', ''] 1845
# ['canned_food', ''] 1846
# ['caviar', ''] 1847
# ['caviar', ''] 1848
# ['caviar', ''] 1849
# ['fresh_fish', ''] 1850
# ['semi_manufactures', ''] 1851
# ['semi_manufactures', 'crab_meat', ''] 1852
# ['fresh_fish', 'smelt', ''] 1853
# ['frozen_fish', ''] 1854
# ['fresh_fish', ''] 1856
# ['caviar', ''] 1857
# ['canned_food', ''] 1858
# ['fresh_fish', 'salmon', ''] 1859
# ['semi_manufactures', ''] 1860
# ['canned_food', 'pate_of_tuna', ''] 1861
# ['canned_food', ''] 1862
# ['caviar', ''] 1864
# ['semi_manufactures', ''] 1865
# ['semi_manufactures', ''] 1866
# ['semi_manufactures', 'crab_meat', ''] 1869
# ['canned_food', ''] 1870
# ['fresh_fish', ''] 1871
# ['caviar', ''] 1872
# ['semi_manufactures', 'soup_set', ''] 1873
# ['canned_food', ''] 1874
# ['caviar', ''] 1875
# ['caviar', 'squash_caviar', ''] 1877
# ['semi_manufactures', ''] 1878
# ['canned_food', 'pate_of_tuna', ''] 1879
# ['canned_food', ''] 1880
# ['caviar', ''] 1881
# ['canned_food', 'sprats', ''] 1882
# ['fresh_fish', ''] 1883
# ['semi_manufactures', ''] 1884
# ['semi_manufactures', 'squid_rings', ''] 1885
# ['semi_manufactures', ''] 1886
# ['semi_manufactures', ''] 1889
# ['semi_manufactures', ''] 1891
# ['semi_manufactures', 'soup_set', ''] 1892
# ['semi_manufactures', 'squid_rings', ''] 1893
# ['semi_manufactures', ''] 1894
# ['semi_manufactures', ''] 1895
# ['frozen_fish', ''] 1896
# ['semi_manufactures', ''] 1897
# ['semi_manufactures', 'salmon_cutlet', ''] 1898
# ['caviar', ''] 1900
# ['caviar', 'black_caviar', ''] 1901
# ['canned_food', 'midii', ''] 1902
# ['caviar', ''] 1903
# ['fresh_fish', ''] 1905
# ['semi_manufactures', ''] 1907
# ['semi_manufactures', ''] 1908
# ['fresh_fish', 'tuna', ''] 1910
# ['semi_manufactures', 'soup_set', ''] 1911
# ['semi_manufactures', ''] 1912
# ['caviar', ''] 1913
# ['caviar', 'red_caviar', ''] 1914
# ['caviar', ''] 1915
# ['caviar', 'red_caviar', ''] 1917
# ['caviar', ''] 1918
# ['fresh_fish', ''] 1920
# ['semi_manufactures', ''] 1921
# ['frozen_fish', ''] 1922
# ['fresh_fish', ''] 1923
# ['fresh_fish', 'codfish', ''] 1924
# ['semi_manufactures', ''] 1925
# ['fresh_fish', ''] 1927
# ['fresh_fish', 'tuna', ''] 1928
# ['semi_manufactures', 'squid_rings', ''] 1929
# ['fresh_fish', ''] 1930
# ['canned_food', ''] 1931
# ['semi_manufactures', ''] 1932
# ['frozen_fish', ''] 1933
# ['canned_food', ''] 1935
# ['semi_manufactures', ''] 1936
# ['semi_manufactures', 'crab_meat', ''] 1938
# ['success_pay_8736', ''] 1940
# ['semi_manufactures', ''] 1942
# ['fresh_fish', ''] 1943
# ['fresh_fish', 'herring', ''] 1945
# ['semi_manufactures', ''] 1946
# ['semi_manufactures', 'crab_meat', ''] 1947
# ['fresh_fish', ''] 1949
# ['fresh_fish', 'crucian', ''] 1950
# ['fresh_fish', ''] 1952
# ['canned_food', ''] 1954
# ['caviar', ''] 1955
# ['caviar', 'squash_caviar', ''] 1956
# ['canned_food', ''] 1957
# ['caviar', ''] 1958
# ['caviar', 'squash_caviar', ''] 1959
# ['caviar', ''] 1960
# ['caviar', 'black_caviar', ''] 1961
# ['canned_food', ''] 1963
# ['canned_food', 'pate_of_tuna', ''] 1964
# ['canned_food', ''] 1965
# ['success_pay_8738', ''] 1967
# ['semi_manufactures', ''] 1970
# ['semi_manufactures', 'stuffing_eel', ''] 1971
# ['caviar', 'squash_caviar', ''] 1972
# ['semi_manufactures', ''] 1974
# ['fresh_fish', ''] 1975
# ['frozen_fish', ''] 1976
# ['fresh_fish', 'salmon', ''] 1977
# ['caviar', ''] 1978
# ['caviar', ''] 1980
# ['fresh_fish', ''] 1981
# ['caviar', 'red_caviar', ''] 1982
# ['fresh_fish', 'crucian', ''] 1983
# ['canned_food', ''] 1986
# ['caviar', ''] 1987
# ['caviar', 'black_caviar', ''] 1988
# ['semi_manufactures', ''] 1989
# ['semi_manufactures', 'crab_meat', ''] 1990
# ['caviar', ''] 1991
# ['canned_food', ''] 1992
# ['frozen_fish', ''] 1993
# ['frozen_fish', 'carp', ''] 1994
# ['fresh_fish', ''] 1996
# ['caviar', ''] 1998
# ['semi_manufactures', ''] 1999
# ['canned_food', 'midii', ''] 2000
# ['frozen_fish', ''] 2002
# ['frozen_fish', 'shark', ''] 2004
# ['caviar', ''] 2005
# ['frozen_fish', ''] 2006
# ['canned_food', ''] 2007
# ['fresh_fish', ''] 2008
# ['fresh_fish', 'marlene', ''] 2009
# ['caviar', 'black_caviar', ''] 2010
# ['semi_manufactures', ''] 2011
# ['success_pay_8741', ''] 2013
# ['caviar', ''] 2014
# ['caviar', 'squash_caviar', ''] 2015
# ['frozen_fish', ''] 2019
# ['caviar', ''] 2020
# ['fresh_fish', ''] 2021
# ['caviar', 'squash_caviar', ''] 2022
# ['canned_food', ''] 2025
# ['canned_food', 'pate_of_tuna', ''] 2026
# ['semi_manufactures', ''] 2027
# ['caviar', ''] 2028
# ['caviar', 'squash_caviar', ''] 2029
# ['frozen_fish', ''] 2032
# ['frozen_fish', ''] 2033
# ['semi_manufactures', 'soup_set', ''] 2034
# ['frozen_fish', 'pike', ''] 2035
# ['frozen_fish', 'peljad', ''] 2036
# ['frozen_fish', ''] 2037
# ['semi_manufactures', ''] 2038
# ['semi_manufactures', 'stuffing_eel', ''] 2039
# ['caviar', ''] 2040
# ['success_pay_8742', ''] 2042
# ['fresh_fish', ''] 2044
# ['semi_manufactures', ''] 2045
# ['fresh_fish', 'codfish', ''] 2046
# ['semi_manufactures', 'crab_meat', ''] 2047
# ['fresh_fish', ''] 2049
# ['fresh_fish', 'marlene', ''] 2050
# ['frozen_fish', ''] 2052
# ['caviar', ''] 2053
# ['frozen_fish', 'peljad', ''] 2054
# ['frozen_fish', ''] 2055
# ['frozen_fish', 'salmon', ''] 2056
# ['semi_manufactures', ''] 2057
# ['semi_manufactures', 'squid_rings', ''] 2058
# ['caviar', 'red_caviar', ''] 2059
# ['success_pay_8744', ''] 2061
# ['frozen_fish', ''] 2063
# ['fresh_fish', ''] 2064
# ['fresh_fish', 'marlene', ''] 2065
# ['success_pay_8743', ''] 2067
# ['semi_manufactures', ''] 2069
# ['frozen_fish', ''] 2070
# ['frozen_fish', 'eel', ''] 2071
# ['semi_manufactures', ''] 2072
# ['semi_manufactures', 'soup_set', ''] 2073
# ['fresh_fish', ''] 2075
# ['fresh_fish', 'marlene', ''] 2076
# ['fresh_fish', ''] 2077
# ['frozen_fish', ''] 2078
# ['frozen_fish', 'salmon', ''] 2079
# ['frozen_fish', ''] 2080
# ['frozen_fish', ''] 2082
# ['frozen_fish', 'pike', ''] 2083
# ['frozen_fish', ''] 2085
# ['frozen_fish', 'pike', ''] 2087
# ['caviar', ''] 2088
# ['frozen_fish', ''] 2089
# ['fresh_fish', ''] 2090
# ['fresh_fish', 'salmon', ''] 2091
# ['frozen_fish', ''] 2092
# ['caviar', 'squash_caviar', ''] 2094
# ['fresh_fish', ''] 2095
# ['fresh_fish', 'crucian', ''] 2096
# ['caviar', ''] 2097
# ['frozen_fish', ''] 2098
# ['caviar', 'squash_caviar', ''] 2099
# ['semi_manufactures', ''] 2100
# ['caviar', ''] 2101
# ['caviar', 'black_caviar', ''] 2102
# ['semi_manufactures', 'squid_rings', ''] 2103
# ['fresh_fish', ''] 2105
# ['fresh_fish', 'smelt', ''] 2106
# ['canned_food', ''] 2107
# ['canned_food', ''] 2109
# ['fresh_fish', ''] 2110
# ['fresh_fish', 'crucian', ''] 2111
# ['semi_manufactures', ''] 2112
# ['semi_manufactures', 'salmon_cutlet', ''] 2113
# ['semi_manufactures', ''] 2114
# ['semi_manufactures', 'salmon_cutlet', ''] 2115
# ['semi_manufactures', ''] 2116
# ['success_pay_8747', ''] 2118
# ['caviar', ''] 2119
# ['caviar', ''] 2121
# ['caviar', 'black_caviar', ''] 2122
# ['caviar', ''] 2123
# ['caviar', 'red_caviar', ''] 2124
# ['caviar', ''] 2125
# ['caviar', 'black_caviar', ''] 2126
# ['semi_manufactures', ''] 2127
# ['caviar', ''] 2129
# ['canned_food', ''] 2131
# ['fresh_fish', ''] 2132
# ['canned_food', ''] 2135
# ['frozen_fish', ''] 2136
# ['canned_food', 'sprats', ''] 2137
# ['frozen_fish', 'pike', ''] 2138
# ['caviar', ''] 2139
# ['caviar', 'red_caviar', ''] 2142
# ['caviar', ''] 2143
# ['semi_manufactures', ''] 2144
# ['canned_food', ''] 2145
# ['caviar', 'red_caviar', ''] 2146
# ['fresh_fish', ''] 2147
# ['fresh_fish', 'tuna', ''] 2148
# ['semi_manufactures', ''] 2149
# ['semi_manufactures', 'crab_meat', ''] 2151
# ['canned_food', ''] 2152
# ['caviar', ''] 2153
# ['caviar', 'black_caviar', ''] 2154
# ['caviar', ''] 2155
# ['frozen_fish', ''] 2156
# ['frozen_fish', 'salmon', ''] 2157
# ['frozen_fish', ''] 2158
# ['frozen_fish', 'shark', ''] 2159
# ['fresh_fish', ''] 2160
# ['fresh_fish', 'salmon', ''] 2161
# ['semi_manufactures', ''] 2163
# ['semi_manufactures', 'crab_meat', ''] 2164
# ['canned_food', ''] 2165
# ['fresh_fish', ''] 2166
# ['semi_manufactures', 'soup_set', ''] 2169
# ['caviar', 'red_caviar', ''] 2170
# ['semi_manufactures', ''] 2172
# ['fresh_fish', ''] 2173
# ['semi_manufactures', 'squid_rings', ''] 2174
# ['semi_manufactures', ''] 2175
# ['fresh_fish', 'marlene', ''] 2176
# ['semi_manufactures', 'stuffing_eel', ''] 2178
# ['caviar', ''] 2180
# ['caviar', 'black_caviar', ''] 2181
# ['caviar', ''] 2182
# ['frozen_fish', ''] 2184
# ['caviar', ''] 2186
# ['frozen_fish', 'pike', ''] 2187
# ['caviar', 'squash_caviar', ''] 2188
# ['caviar', ''] 2190
# ['frozen_fish', ''] 2191
# ['caviar', 'red_caviar', ''] 2192
# ['caviar', ''] 2193
# ['semi_manufactures', ''] 2194
# ['frozen_fish', ''] 2195
# ['fresh_fish', ''] 2197
# ['canned_food', ''] 2198
# ['caviar', 'red_caviar', ''] 2199
# ['caviar', ''] 2200
# ['canned_food', 'sprats', ''] 2201
# ...
# ['frozen_fish', ''] 23599
# ['frozen_fish', 'peljad', ''] 23601
# ['fresh_fish', 'tuna', ''] 23602
# ['frozen_fish', 'carp', ''] 23603
# ['caviar', ''] 23604
# ['fresh_fish', ''] 23605
# ['fresh_fish', ''] 23606
# ['fresh_fish', 'marlene', ''] 23607
# ['semi_manufactures', ''] 23608
# ['fresh_fish', ''] 23610
# ['fresh_fish', 'salmon', ''] 23611
# ['semi_manufactures', 'soup_set', ''] 23612
# ['semi_manufactures', ''] 23613
# ['canned_food', 'midii', ''] 23614
# ['canned_food', ''] 23615
# ['semi_manufactures', 'squid_rings', ''] 23616
# ['canned_food', 'midii', ''] 23617
# ['fresh_fish', 'tuna', ''] 23618
# ['canned_food', ''] 23620
# ['canned_food', ''] 23622
# ['semi_manufactures', ''] 23624
# ['canned_food', 'pate_of_tuna', ''] 23625
# ['frozen_fish', ''] 23627
# ['canned_food', ''] 23628
# ['semi_manufactures', ''] 23629
# ['canned_food', 'pate_of_tuna', ''] 23630
# ['semi_manufactures', ''] 23632
# ['fresh_fish', ''] 23633
# ['canned_food', ''] 23635
# ['frozen_fish', ''] 23636
# ['canned_food', ''] 23637
# ['caviar', ''] 23638
# ['caviar', 'squash_caviar', ''] 23639
# ['fresh_fish', ''] 23640
# ['caviar', 'red_caviar', ''] 23641
# ['caviar', ''] 23642
# ['caviar', 'red_caviar', ''] 23643
# ['frozen_fish', 'carp', ''] 23644
# ['canned_food', ''] 23645
# ['canned_food', 'pate_of_tuna', ''] 23646
# ['caviar', ''] 23647
# ['fresh_fish', ''] 23648
# ['fresh_fish', 'herring', ''] 23650
# ['fresh_fish', ''] 23651
# ['frozen_fish', ''] 23653
# ['canned_food', ''] 23654
# ['success_pay_9758', ''] 23656
# ['frozen_fish', 'carp', ''] 23657
# ['frozen_fish', ''] 23659
# ['success_pay_9759', ''] 23661
# ['canned_food', ''] 23663
# ['canned_food', 'midii', ''] 23664
# ['caviar', ''] 23666
# ['caviar', 'black_caviar', ''] 23667
# ['caviar', ''] 23668
# ['caviar', 'black_caviar', ''] 23669
# ['caviar', ''] 23670
# ['caviar', 'red_caviar', ''] 23671
# ['caviar', ''] 23672
# ['caviar', 'red_caviar', ''] 23673
# ['caviar', ''] 23674
# ['fresh_fish', ''] 23675
# ['caviar', ''] 23677
# ['caviar', 'black_caviar', ''] 23678
# ['semi_manufactures', ''] 23680
# ['semi_manufactures', 'salmon_cutlet', ''] 23681
# ['canned_food', ''] 23682
# ['canned_food', 'sprats', ''] 23683
# ['fresh_fish', ''] 23685
# ['fresh_fish', 'marlene', ''] 23686
# ['semi_manufactures', ''] 23688
# ['semi_manufactures', 'soup_set', ''] 23689
# ['semi_manufactures', ''] 23690
# ['canned_food', ''] 23691
# ['caviar', ''] 23693
# ['caviar', 'black_caviar', ''] 23694
# ['caviar', ''] 23695
# ['fresh_fish', ''] 23697
# ['fresh_fish', 'marlene', ''] 23698
# ['caviar', ''] 23700
# ['caviar', 'squash_caviar', ''] 23701
# ['caviar', ''] 23702
# ['caviar', 'black_caviar', ''] 23703
# ['caviar', ''] 23704
# ['semi_manufactures', ''] 23705
# ['semi_manufactures', 'soup_set', ''] 23706
# ['semi_manufactures', ''] 23707
# ['semi_manufactures', 'salmon_cutlet', ''] 23708
# ['success_pay_9761', ''] 23710
# ['fresh_fish', 'smelt', ''] 23711
# ['frozen_fish', ''] 23712
# ['canned_food', ''] 23713
# ['fresh_fish', ''] 23714
# ['fresh_fish', 'smelt', ''] 23715
# ['fresh_fish', ''] 23716
# ['fresh_fish', 'herring', ''] 23717
# ['fresh_fish', ''] 23718
# ['caviar', ''] 23719
# ['caviar', 'black_caviar', ''] 23720
# ['caviar', ''] 23721
# ['caviar', 'red_caviar', ''] 23722
# ['success_pay_9762', ''] 23725
# ['caviar', ''] 23728
# ['fresh_fish', ''] 23730
# ['frozen_fish', 'eel', ''] 23731
# ['caviar', ''] 23732
# ['caviar', ''] 23733
# ['caviar', 'squash_caviar', ''] 23734
# ['caviar', 'squash_caviar', ''] 23735
# ['caviar', ''] 23736
# ['caviar', 'black_caviar', ''] 23737
# ['caviar', ''] 23739
# ['canned_food', ''] 23741
# ['caviar', ''] 23742
# ['semi_manufactures', ''] 23744
# ['semi_manufactures', ''] 23745
# ['semi_manufactures', 'squid_rings', ''] 23746
# ['semi_manufactures', 'salmon_cutlet', ''] 23747
# ['semi_manufactures', ''] 23748
# ['semi_manufactures', ''] 23750
# ['semi_manufactures', ''] 23751
# ['success_pay_9764', ''] 23754
# ['semi_manufactures', 'salmon_cutlet', ''] 23755
# ['semi_manufactures', ''] 23756
# ['fresh_fish', 'marlene', ''] 23758
# ['frozen_fish', ''] 23759
# ['caviar', ''] 23760
# ['canned_food', ''] 23763
# ['canned_food', 'sprats', ''] 23764
# ['frozen_fish', 'pike', ''] 23765
# ['frozen_fish', 'pike', ''] 23766
# ['canned_food', ''] 23767
# ['frozen_fish', ''] 23768
# ['canned_food', ''] 23769
# ['fresh_fish', ''] 23770
# ['fresh_fish', 'codfish', ''] 23771
# ['fresh_fish', ''] 23773
# ['canned_food', ''] 23775
# ['semi_manufactures', ''] 23776
# ['fresh_fish', 'smelt', ''] 23777
# ['frozen_fish', ''] 23778
# ['canned_food', 'pate_of_tuna', ''] 23779
# ['canned_food', ''] 23781
# ['frozen_fish', ''] 23782
# ['canned_food', 'sprats', ''] 23784
# ['semi_manufactures', ''] 23785
# ['semi_manufactures', 'crab_meat', ''] 23786
# ['canned_food', 'sprats', ''] 23787
# ['semi_manufactures', ''] 23789
# ['canned_food', ''] 23790
# ['frozen_fish', ''] 23792
# ['fresh_fish', ''] 23793
# ['canned_food', ''] 23794
# ['frozen_fish', 'carp', ''] 23795
# ['frozen_fish', ''] 23797
# ['caviar', ''] 23798
# ['semi_manufactures', 'stuffing_eel', ''] 23799
# ['frozen_fish', ''] 23800
# ['frozen_fish', 'peljad', ''] 23801
# ['semi_manufactures', ''] 23802
# ['frozen_fish', ''] 23803
# ['frozen_fish', 'salmon', ''] 23804
# ['caviar', ''] 23806
# ['semi_manufactures', 'crab_meat', ''] 23807
# ['canned_food', ''] 23808
# ['semi_manufactures', ''] 23809
# ['canned_food', ''] 23810
# ['canned_food', 'pate_of_tuna', ''] 23811
# ['caviar', 'black_caviar', ''] 23812
# ['canned_food', ''] 23813
# ['semi_manufactures', 'crab_meat', ''] 23814
# ['fresh_fish', ''] 23815
# ['fresh_fish', ''] 23816
# ['frozen_fish', ''] 23817
# ['frozen_fish', ''] 23818
# ['success_pay_9767', ''] 23821
# ['caviar', ''] 23822
# ['canned_food', ''] 23823
# ['semi_manufactures', ''] 23824
# ['semi_manufactures', 'salmon_cutlet', ''] 23825
# ['semi_manufactures', ''] 23826
# ['frozen_fish', ''] 23828
# ['caviar', ''] 23830
# ['canned_food', ''] 23832
# ['canned_food', 'sprats', ''] 23833
# ['fresh_fish', ''] 23834
# ['fresh_fish', 'crucian', ''] 23835
# ['semi_manufactures', ''] 23836
# ['canned_food', ''] 23837
# ['canned_food', 'midii', ''] 23838
# ['canned_food', ''] 23839
# ['canned_food', 'sprats', ''] 23840
# ['semi_manufactures', ''] 23841
# ['semi_manufactures', ''] 23843
# ['semi_manufactures', 'stuffing_eel', ''] 23847
# ['caviar', 'red_caviar', ''] 23848
# ['caviar', ''] 23849
# ['fresh_fish', ''] 23850
# ['fresh_fish', 'marlene', ''] 23851
# ['semi_manufactures', ''] 23852
# ['fresh_fish', ''] 23853
# ['fresh_fish', 'tuna', ''] 23854
# ['fresh_fish', ''] 23855
# ['fresh_fish', ''] 23856
# ['fresh_fish', 'tuna', ''] 23857
# ['semi_manufactures', ''] 23858
# ['canned_food', ''] 23861
# ['canned_food', 'pate_of_tuna', ''] 23862
# ['semi_manufactures', ''] 23863
# ['canned_food', ''] 23864
# ['canned_food', ''] 23865
# ['semi_manufactures', ''] 23866
# ['caviar', ''] 23867
# ['semi_manufactures', 'soup_set', ''] 23868
# ['frozen_fish', ''] 23869
# ['semi_manufactures', ''] 23870
# ['frozen_fish', ''] 23871
# ['success_pay_9769', ''] 23874
# ['caviar', ''] 23875
# ['frozen_fish', 'eel', ''] 23876
# ['caviar', 'black_caviar', ''] 23877
# ['semi_manufactures', ''] 23878
# ['canned_food', ''] 23879
# ['canned_food', 'midii', ''] 23880
# ['canned_food', ''] 23881
# ['fresh_fish', ''] 23882
# ['fresh_fish', 'crucian', ''] 23883
# ['canned_food', ''] 23885
# ['canned_food', 'midii', ''] 23886
# ['fresh_fish', ''] 23887
# ['semi_manufactures', ''] 23888
# ['fresh_fish', ''] 23889
# ['canned_food', ''] 23890
# ['caviar', ''] 23891
# ['success_pay_9771', ''] 23893
# ['semi_manufactures', ''] 23895
# ['caviar', ''] 23897
# ['caviar', 'black_caviar', ''] 23898
# ['semi_manufactures', ''] 23899
# ['caviar', ''] 23900
# ['semi_manufactures', 'squid_rings', ''] 23901
# ['fresh_fish', ''] 23902
# ['fresh_fish', 'crucian', ''] 23904
# ['canned_food', ''] 23906
# ['canned_food', ''] 23907
# ['caviar', ''] 23908
# ['caviar', ''] 23910
# ['fresh_fish', ''] 23911
# ['caviar', 'squash_caviar', ''] 23912
# ['fresh_fish', 'salmon', ''] 23913
# ['fresh_fish', ''] 23914
# ['frozen_fish', ''] 23915
# ['frozen_fish', 'carp', ''] 23916
# ['caviar', ''] 23917
# ['frozen_fish', ''] 23918
# ['canned_food', ''] 23919
# ['caviar', 'black_caviar', ''] 23920
# ['canned_food', 'sprats', ''] 23921
# ['canned_food', ''] 23922
# ['frozen_fish', 'peljad', ''] 23923
# ['canned_food', 'pate_of_tuna', ''] 23925
# ['frozen_fish', ''] 23927
# ['canned_food', ''] 23928
# ['frozen_fish', 'peljad', ''] 23929
# ['canned_food', 'midii', ''] 23930
# ['canned_food', ''] 23931
# ['caviar', ''] 23932
# ['semi_manufactures', ''] 23933
# ['caviar', 'black_caviar', ''] 23934
# ['canned_food', 'sprats', ''] 23935
# ['frozen_fish', ''] 23936
# ['caviar', 'red_caviar', ''] 23938
# ['canned_food', ''] 23939
# ['fresh_fish', ''] 23941
# ['semi_manufactures', ''] 23942
# ['fresh_fish', 'tuna', ''] 23943
# ['semi_manufactures', ''] 23945
# ['semi_manufactures', 'crab_meat', ''] 23946
# ['caviar', ''] 23947
# ['semi_manufactures', ''] 23949
# ['frozen_fish', ''] 23950
# ['caviar', ''] 23953
# ['caviar', 'black_caviar', ''] 23954
# ['caviar', ''] 23955
# ['success_pay_9774', ''] 23957
# ['frozen_fish', 'peljad', ''] 23958
# ['frozen_fish', ''] 23959
# ['frozen_fish', 'eel', ''] 23960
# ['frozen_fish', ''] 23961
# ['success_pay_9772', ''] 23964
# ['frozen_fish', ''] 23966
# ['semi_manufactures', ''] 23968
# ['frozen_fish', 'carp', ''] 23969
# ['caviar', ''] 23970
# ['frozen_fish', ''] 23973
# ['frozen_fish', ''] 23974
# ['fresh_fish', ''] 23975
# ['frozen_fish', 'eel', ''] 23976
# ['fresh_fish', 'salmon', ''] 23977
# ['frozen_fish', ''] 23978
# ['fresh_fish', ''] 23979
# ['fresh_fish', ''] 23980
# ['fresh_fish', 'tuna', ''] 23981
# ['fresh_fish', 'crucian', ''] 23983
# ['frozen_fish', 'pike', ''] 23985
# ['frozen_fish', ''] 23986
# ['fresh_fish', ''] 23987
# ['semi_manufactures', ''] 23988
# ['caviar', ''] 23990
# ['semi_manufactures', ''] 23991
# ['caviar', ''] 23992
# ['semi_manufactures', 'soup_set', ''] 23994
# ['caviar', ''] 23995
# ['canned_food', ''] 23996
# ['canned_food', ''] 23997
# ['canned_food', 'midii', ''] 23998
# ['canned_food', 'midii', ''] 23999
# ['frozen_fish', ''] 24000
# ['fresh_fish', ''] 24002
# ['semi_manufactures', ''] 24005
# ['canned_food', ''] 24006
# ['success_pay_9776', ''] 24008
# ['semi_manufactures', ''] 24010
# ['frozen_fish', ''] 24012
# ['canned_food', ''] 24013
# ['canned_food', 'pate_of_tuna', ''] 24014
# ['semi_manufactures', ''] 24016
# ['success_pay_9775', ''] 24018
# ['fresh_fish', 'smelt', ''] 24021
# ['canned_food', ''] 24022
# ['fresh_fish', ''] 24023
# ['fresh_fish', 'smelt', ''] 24024
# ['fresh_fish', ''] 24025
# ['canned_food', 'sprats', ''] 24026
# ['fresh_fish', 'salmon', ''] 24027
# ['caviar', ''] 24028
# ['fresh_fish', ''] 24029
# ['frozen_fish', ''] 24031
# ['frozen_fish', 'peljad', ''] 24032
# ['frozen_fish', ''] 24033
# ['canned_food', ''] 24034
# ['frozen_fish', ''] 24035
# ['semi_manufactures', ''] 24036
# ['caviar', ''] 24039
# ['caviar', 'black_caviar', ''] 24040
# ['fresh_fish', ''] 24042
# ['semi_manufactures', ''] 24043
# ['fresh_fish', ''] 24044
# ['success_pay_9777', ''] 24046
# ['frozen_fish', ''] 24048
# ['semi_manufactures', ''] 24049
# ['semi_manufactures', 'squid_rings', ''] 24050
# ['semi_manufactures', ''] 24051
# ['frozen_fish', ''] 24053
# ['frozen_fish', 'shark', ''] 24054
# ['frozen_fish', ''] 24055
# ['frozen_fish', 'salmon', ''] 24056
# ['frozen_fish', ''] 24057
# ['fresh_fish', ''] 24059
# ['canned_food', ''] 24060
# ['canned_food', 'pate_of_tuna', ''] 24061
# ['canned_food', ''] 24062
# ['canned_food', 'pate_of_tuna', ''] 24064
# ['semi_manufactures', ''] 24065
# ['frozen_fish', ''] 24066
# ['canned_food', ''] 24068
# ['canned_food', ''] 24069
# ['canned_food', 'sprats', ''] 24070
# ['caviar', ''] 24071
# ['caviar', 'red_caviar', ''] 24072
# ['canned_food', ''] 24074
# ['fresh_fish', ''] 24076
# ['frozen_fish', ''] 24077
# ['frozen_fish', ''] 24078
# ['frozen_fish', 'shark', ''] 24079
# ['caviar', ''] 24081
# ['caviar', 'red_caviar', ''] 24082
# ['fresh_fish', ''] 24083
# ['frozen_fish', ''] 24085
# ['caviar', ''] 24087
# ['fresh_fish', ''] 24088
# ['frozen_fish', ''] 24089
# ['caviar', ''] 24091
# ['frozen_fish', 'peljad', ''] 24093
# ['frozen_fish', ''] 24094
# ['semi_manufactures', ''] 24095
# ['semi_manufactures', ''] 24096
# ['semi_manufactures', 'crab_meat', ''] 24097
# ['semi_manufactures', 'soup_set', ''] 24098
# ['success_pay_9781', ''] 24100
# ['semi_manufactures', ''] 24101
# ['semi_manufactures', 'stuffing_eel', ''] 24102
# ['semi_manufactures', ''] 24103
# ['fresh_fish', ''] 24105
# ['fresh_fish', ''] 24107
# ['frozen_fish', ''] 24108
# ['frozen_fish', 'shark', ''] 24109
# ['frozen_fish', ''] 24111
# ['frozen_fish', 'pike', ''] 24112
# ['caviar', ''] 24113
# ['semi_manufactures', ''] 24114
# ['caviar', ''] 24115
# ['semi_manufactures', 'stuffing_eel', ''] 24116
# ['caviar', 'squash_caviar', ''] 24117
# ['semi_manufactures', ''] 24118
# ['fresh_fish', ''] 24119
# ['fresh_fish', 'salmon', ''] 24120
# ['caviar', ''] 24121
# ['frozen_fish', ''] 24122
# ['caviar', ''] 24123
# ['caviar', 'black_caviar', ''] 24124
# ['frozen_fish', ''] 24125
# ['fresh_fish', ''] 24128
# ['canned_food', ''] 24129
# ['canned_food', 'pate_of_tuna', ''] 24130
# ['canned_food', 'sprats', ''] 24131
# ['fresh_fish', 'crucian', ''] 24132
# ['semi_manufactures', ''] 24135
# ['semi_manufactures', 'crab_meat', ''] 24136
# ['semi_manufactures', 'stuffing_eel', ''] 24138
# ['frozen_fish', ''] 24140
# ['semi_manufactures', ''] 24142
# ['semi_manufactures', 'crab_meat', ''] 24143
# ['caviar', ''] 24144
# ['canned_food', ''] 24145
# ['caviar', 'squash_caviar', ''] 24146
# ['caviar', ''] 24147
# ['semi_manufactures', ''] 24148
# ['canned_food', ''] 24150
# ['canned_food', 'sprats', ''] 24153
# ['frozen_fish', ''] 24155
# ['caviar', 'squash_caviar', ''] 24156
# ['frozen_fish', 'peljad', ''] 24157
# ['caviar', ''] 24158
# ['canned_food', ''] 24159
# ['canned_food', ''] 24161
# ['semi_manufactures', ''] 24162
# ['canned_food', 'midii', ''] 24163
# ['caviar', ''] 24164
# ['canned_food', ''] 24165
# ['semi_manufactures', 'squid_rings', ''] 24166
# ['canned_food', 'pate_of_tuna', ''] 24167
# ['canned_food', ''] 24168
# ['fresh_fish', ''] 24170
# ['canned_food', ''] 24172
# ['canned_food', 'sprats', ''] 24173
# ['frozen_fish', ''] 24174
# ['caviar', ''] 24175
# ['canned_food', 'midii', ''] 24177
# ['canned_food', ''] 24178
# ['canned_food', 'sprats', ''] 24179
# ['frozen_fish', 'carp', ''] 24180
# ['semi_manufactures', ''] 24181
# ['frozen_fish', ''] 24182
# ['canned_food', ''] 24184
# ['semi_manufactures', ''] 24185
# ['frozen_fish', ''] 24186
# ['success_pay_9784', ''] 24188
# ['semi_manufactures', 'crab_meat', ''] 24189
# ['canned_food', ''] 24190
# ['canned_food', 'midii', ''] 24191
# ['canned_food', ''] 24193
# ['canned_food', 'midii', ''] 24194
# ['canned_food', ''] 24195
# ['fresh_fish', ''] 24196
# ['success_pay_9785', ''] 24198
# ['frozen_fish', ''] 24201
# ['semi_manufactures', ''] 24202
# ['caviar', ''] 24204
# ['canned_food', ''] 24205
# ['canned_food', 'pate_of_tuna', ''] 24206
# ['caviar', 'red_caviar', ''] 24207
# ['caviar', ''] 24208
# ['canned_food', ''] 24209
# ['fresh_fish', ''] 24211
# ['canned_food', ''] 24212
# ['caviar', ''] 24213
# ['caviar', 'squash_caviar', ''] 24214
# ['caviar', ''] 24215
# ['canned_food', 'midii', ''] 24217
# ['canned_food', ''] 24218
# ['caviar', 'black_caviar', ''] 24219
# ['frozen_fish', ''] 24220
# ['caviar', 'red_caviar', ''] 24221
# ['fresh_fish', ''] 24223
# ['fresh_fish', ''] 24225
# ['fresh_fish', 'smelt', ''] 24226
# ['fresh_fish', 'marlene', ''] 24227
# ['canned_food', ''] 24228
# ['caviar', ''] 24229
# ['canned_food', 'midii', ''] 24231
# ['frozen_fish', ''] 24233
# ['frozen_fish', 'carp', ''] 24235
# ['fresh_fish', ''] 24236
# ['canned_food', ''] 24237
# ['caviar', ''] 24239
# ['frozen_fish', ''] 24240
# ['fresh_fish', ''] 24241
# ['semi_manufactures', ''] 24242
# ['canned_food', ''] 24243
# ['canned_food', 'midii', ''] 24244
# ['caviar', ''] 24246
# ['fresh_fish', 'salmon', ''] 24247
# ['caviar', ''] 24249
# ['caviar', 'red_caviar', ''] 24250
# ['fresh_fish', ''] 24252
# ['semi_manufactures', ''] 24253
# ['semi_manufactures', 'salmon_cutlet', ''] 24254
# ['semi_manufactures', ''] 24255
# ['semi_manufactures', ''] 24256
# ['fresh_fish', ''] 24257
# ['fresh_fish', ''] 24259
# ['semi_manufactures', 'salmon_cutlet', ''] 24261
# ['success_pay_9788', ''] 24263
# ['fresh_fish', ''] 24264
# ['success_pay_9787', ''] 24266
# ['frozen_fish', 'eel', ''] 24268
# ['frozen_fish', ''] 24269
# ['frozen_fish', 'eel', ''] 24270
# ['frozen_fish', ''] 24271
# ['frozen_fish', 'carp', ''] 24272
# ['frozen_fish', ''] 24273
# ['frozen_fish', 'carp', ''] 24274
# ['semi_manufactures', ''] 24276
# ['semi_manufactures', 'salmon_cutlet', ''] 24277
# ['fresh_fish', ''] 24278
# ['canned_food', ''] 24280
# ['canned_food', 'pate_of_tuna', ''] 24281
# ['success_pay_9790', ''] 24283

# %%
# def split(item):
#     return item.split('/')

# %%
# df['tovar'] = np.nan
# df
# Out:
#                       date      time          id               ip  \
# 0      2018-08-01 00:01:47  00:01:47  [E522JAEQ]  121.165.118.201
# 1      2018-08-01 00:04:27  00:04:27  [C0182Y6W]  121.165.118.201
# 2      2018-08-01 00:07:25  00:07:25  [GQY4K4H9]  121.165.118.201
# 3      2018-08-01 00:07:54  00:07:54  [ENZOWBC9]  121.165.118.201
# 4      2018-08-01 00:08:58  00:08:58  [7OEXWZ78]  121.165.118.201
# ...                    ...       ...         ...              ...
# 20567  2018-08-14 09:51:05  09:51:05  [1K0JJ1P7]   147.144.255.18
# 20568  2018-08-14 09:53:06  09:53:06  [PANSGPA1]   147.144.255.18
# 20569  2018-08-14 09:53:56  09:53:56  [QBV4IHFK]   147.144.255.18
# 20570  2018-08-14 09:53:56  09:53:56  [ZLZ4QXWB]   147.144.255.18
# 20571  2018-08-14 09:53:56  09:53:56  [2O1CTP7M]   147.144.255.18
#
#                                      action tovar
# 0                               fresh_fish/  test
# 1                              canned_food/
# 2                        semi_manufactures/
# 3                              canned_food/
# 4                        semi_manufactures/
# ...                                     ...   ...
# 20567                           fresh_fish/
# 20568                          canned_food/
# 20569             canned_food/pate_of_tuna/
# 20570  pay?user_id=81416246280&cart_id=9790
# 20571                     success_pay_9790/
#
# [20572 rows x 6 columns]
